# %% [markdown]
# # Working with Geolocated Data
# ---

# %% [markdown]
# ### Exercise: Earthquake Monitor

# %% [markdown]
# Collect the data:

# %%
import requests

endpoint = "https://earthquake.usgs.gov/fdsnws/event/1/query?"

ps = { "format": "csv", 
       "starttime": "2023-08-28", 
       "endtime": "2023-09-28",
       "minmagnitude": 5
     }

response = requests.get(endpoint, params=ps)

import pandas as pd
import io

buf = io.StringIO(response.text) 
data = pd.read_csv(buf)

# %% [markdown]
# The available information about each earthquake:

# %%
for col in data.columns:
    print(col)
# Out:
# time
# latitude
# longitude
# depth
# mag
# magType
# nst
# gap
# dmin
# rms
# net
# id
# updated
# place
# type
# horizontalError
# depthError
# magError
# magNst
# status
# locationSource
# magSource

# %% [markdown]
# Draw the map:

# %%
import folium

greenwich_coords = [51.4769, 0]  # i.e. [Latitude, Longitude]

world_map = folium.Map(location=greenwich_coords,
                                zoom_start = 1)

# Add markers
for i in range(len(data)):
    quake = data.iloc[i,:]
    folium.Marker(location=[quake.latitude,quake.longitude], 
                  popup = quake.mag
                 ).add_to(world_map)


world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_229588c9bfe42daa0cef1a04473e65f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_229588c9bfe42daa0cef1a04473e65f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_229588c9bfe42daa0cef1a04473e65f9 = L.map(
#                 &quot;map_229588c9bfe42daa0cef1a04473e65f9&quot;,
#                 {
#                     center: [51.4769, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f1583c5990b464fb2dca6bce96c2425 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0f1583c5990b464fb2dca6bce96c2425.addTo(map_229588c9bfe42daa0cef1a04473e65f9);
#
#
#             var marker_7eba31b57dd4bc946b3f1034eded5b08 = L.marker(
#                 [0.8622, 93.1129],
#                 {}
#             ).addTo(map_229588c9bfe42daa0cef1a04473e65f9);
#
#
#         var popup_f84ce15e2404843fafcff22bd2e04f37 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef0609931a69019e811bf549b18251ac = $(`&lt;div id=&quot;html_ef0609931a69019e811bf549b18251ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.5&lt;/div&gt;`)[0];
#                 popup_f84ce15e2404843fafcff22bd2e04f37.setContent(html_ef0609931a69019e811bf549b18251ac);
#
#
#
#         marker_7eba31b57dd4bc946b3f1034eded5b08.bindPopup(popup_f84ce15e2404843fafcff22bd2e04f37)
#         ;
#
#
#
#
#             var marker_9f95aafe0e83f0db4b6f3fd0db869b38 = L.marker(
#                 [-53.5274, -134.774],
#                 {}
#             ).addTo(map_229588c9bfe42daa0cef1a04473e65f9);
#
#
#         var popup_41c34aa780b5591cf7432140ed6fd37b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4b3b850fba1c01b4efbc6aa1b3da4c0 = $(`&lt;div id=&quot;html_f4b3b850fba1c01b4efbc6aa1b3da4c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.6&lt;/div&gt;`)[0];
#                 popup_41c34aa780b5591cf7432140ed6fd37b.setContent(html_f4b3b850fba1c01b4efbc6aa1b3da4c0);
#
#
#
#         marker_9f95aafe0e83f0db4b6f3fd0db869b38.bindPopup(popup_41c34aa780b5591cf7432140ed6fd37b)
#         ;
#
#
#
#
#             var marker_0535985465367834ff1a1978c12a9237 = L.marker(
#                 [-3.3385, 128.858],
#                 {}
#             ).addTo(map_229588c9bfe42daa0cef1a04473e65f9);
#
#
#         var popup_8fa1fae4ab9233ddfb7258da7a706440 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0716def4f27482991139935bf3ef35cb = $(`&lt;div id=&quot;html_0716def4f27482991139935bf3ef35cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.0&lt;/div&gt;`)[0];
#                 popup_8fa1fae4ab9233ddfb7258da7a706440.setContent(html_0716def4f27482991139935bf3ef35cb);
#
#
#
#         marker_0535985465367834ff1a1978c12a9237.bindPopup(popup_8fa1fae4ab9233ddfb7258da7a706440)
#         ;
#
#
#
#
#             var marker_3f77cc1f9fc1d2251379b0d437b7c7f0 = L.marker(
#                 [31.4154, 141.7419],
#                 {}
#             ).addTo(map_229588c9bfe42daa0cef1a04473e65f9);
#
#
#         var popup_e683223f03d5a09a9bc0302658255a45 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d69cf906b2c6fb352838cda422f1b62 = $(`&lt;div id=&quot;html_0d69cf906b2c6fb352838cda422f1b62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.0&lt;/div&gt;`)[0];
#                 popup_e683223f03d5a09a9bc0302658255a45.setContent(html_0d69cf906b2c6fb352838cda422f1b62);
#
#
#
#         marker_3f77cc1f9fc1d2251379b0d437b7c7f0.bindPopup(popup_e683223f03d5a09a9bc0302658255a45)
#         ;
#
#
#
#
#             var marker_1039c39531f6a04e8f2888dd673d71ec = L.marker(
#                 [-23.4315, -179.8079],
#                 {}
#             ).addTo(map_229588c9bfe42daa0cef1a04473e65f9);
#
#
#         var popup_311f8cddcfff986a3777c82ec5933512 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23d345d11b94bca6213ff30a9e19e047 = $(`&lt;div id=&quot;html_23d345d11b94bca6213ff30a9e19e047&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.2&lt;/div&gt;`)[0];
#                 popup_311f8cddcfff986a3777c82ec5933512.setContent(html_23d345d11b94bca6213ff30a9e19e047);
#
#
#
#         marker_1039c39531f6a04e8f2888dd673d71ec.bindPopup(popup_311f8cddcfff986a3777c82ec5933512)
#         ;
#
#
#
#
#             var marker_0044887c8a87830d9df528fc36754261 = L.marker(
#                 [15.0877, -104.3164],
#                 {}
#             ).addTo(map_229588c9bfe42daa0cef1a04473e65f9);
#
#
#         var popup_307ab71d95053713cbda591f1f80e8ea = L.popup(

# %% [markdown]
# Again but with `folium.CircleMarker`:

# %%
import folium

greenwich_coords = [51.4769, 0]  # i.e. [Latitude, Longitude]

world_map = folium.Map(location=greenwich_coords,
                                zoom_start = 1)

# Add markers
for i in range(len(data)):
    quake = data.iloc[i,:]
    folium.CircleMarker(location=[quake.latitude,quake.longitude], 
                        popup = quake.mag,
                        weight=1,
                        fill=True,
                        fill_opacity=0.3,
                        radius = quake.mag * 2
                       ).add_to(world_map)


world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b0bb071281dce40c0bb6c42f04bb29fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b0bb071281dce40c0bb6c42f04bb29fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b0bb071281dce40c0bb6c42f04bb29fe = L.map(
#                 &quot;map_b0bb071281dce40c0bb6c42f04bb29fe&quot;,
#                 {
#                     center: [51.4769, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_067789e6976836e070f31d84351dabe2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_067789e6976836e070f31d84351dabe2.addTo(map_b0bb071281dce40c0bb6c42f04bb29fe);
#
#
#             var circle_marker_f26706b9e97025514fdef885d0f64f0c = L.circleMarker(
#                 [0.8622, 93.1129],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_b0bb071281dce40c0bb6c42f04bb29fe);
#
#
#         var popup_df6fc85ad63bf15e01e1f09471e805b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1edcd877139b250c0976a876cd4fca73 = $(`&lt;div id=&quot;html_1edcd877139b250c0976a876cd4fca73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.5&lt;/div&gt;`)[0];
#                 popup_df6fc85ad63bf15e01e1f09471e805b6.setContent(html_1edcd877139b250c0976a876cd4fca73);
#
#
#
#         circle_marker_f26706b9e97025514fdef885d0f64f0c.bindPopup(popup_df6fc85ad63bf15e01e1f09471e805b6)
#         ;
#
#
#
#
#             var circle_marker_c4a10e68c6377571afab26b3c1513b9a = L.circleMarker(
#                 [-53.5274, -134.774],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.2, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_b0bb071281dce40c0bb6c42f04bb29fe);
#
#
#         var popup_410ce182392f260733a53917129299de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c20824dff93a21689611f7c12dec628 = $(`&lt;div id=&quot;html_1c20824dff93a21689611f7c12dec628&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.6&lt;/div&gt;`)[0];
#                 popup_410ce182392f260733a53917129299de.setContent(html_1c20824dff93a21689611f7c12dec628);
#
#
#
#         circle_marker_c4a10e68c6377571afab26b3c1513b9a.bindPopup(popup_410ce182392f260733a53917129299de)
#         ;
#
#
#
#
#             var circle_marker_ab7b5c7c3ee032c1f5e3ef6cde5efdcf = L.circleMarker(
#                 [-3.3385, 128.858],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_b0bb071281dce40c0bb6c42f04bb29fe);
#
#
#         var popup_76bcdc68a5b31576f29b82c873495eba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9963ad04aa56ab8b085500d8d37ab2ab = $(`&lt;div id=&quot;html_9963ad04aa56ab8b085500d8d37ab2ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.0&lt;/div&gt;`)[0];
#                 popup_76bcdc68a5b31576f29b82c873495eba.setContent(html_9963ad04aa56ab8b085500d8d37ab2ab);
#
#
#
#         circle_marker_ab7b5c7c3ee032c1f5e3ef6cde5efdcf.bindPopup(popup_76bcdc68a5b31576f29b82c873495eba)
#         ;
#
#
#
#
#             var circle_marker_954df812f1bb8b0739b2387e7d2e7127 = L.circleMarker(
#                 [31.4154, 141.7419],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillR

# %% [markdown]
# For the colouring, we need to request the GeoJSON data:

# %%
endpoint = "https://earthquake.usgs.gov/fdsnws/event/1/query?"

ps = { "format": "geojson", 
       "starttime": "2023-08-28", 
       "endtime": "2023-09-28",
       "minmagnitude": 5 
     }

response = requests.get(endpoint, params=ps)

import json
data_dict = json.loads(response.text)

# %% [markdown]
# Let's inspect the first earthquake record:

# %%
quake = data_dict['features'][0]
quake
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 5.5,
#   'place': 'off the west coast of northern Sumatra',
#   'time': 1695836841596,
#   'updated': 1702159240040,
#   'tz': None,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000lb60',
#   'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000lb60&format=geojson',
#   'felt': None,
#   'cdi': None,
#   'mmi': 0,
#   'alert': 'green',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'sig': 465,
#   'net': 'us',
#   'code': '6000lb60',
#   'ids': ',usauto6000lb60,pt23270000,us6000lb60,',
#   'sources': ',usauto,pt,us,',
#   'types': ',internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#   'nst': 101,
#   'dmin': 4.483,
#   'rms': 0.68,
#   'gap': 25,
#   'magType': 'mww',
#   'type': 'earthquake',
#   'title': 'M 5.5 - off the west coast of northern Sumatra'},
#  'geometry': {'type': 'Point', 'coordinates': [93.1129, 0.8622, 10]},
#  'id': 'us6000lb60'}

# %% [markdown]
# Notice that the position is given by

# %%
quake['geometry']['coordinates']
# Out:
# [93.1129, 0.8622, 10]

# %% [markdown]
# which is in the format [longitude, latitude, depth].

# %% [markdown]
# The other information can be retrieved as e.g.

# %%
quake['properties']['mag']
# Out:
# 5.5

# %%
import folium

greenwich_coords = [51.4769, 0]  # i.e. [Latitude, Longitude]

world_map = folium.Map(location=greenwich_coords,
                                zoom_start = 1)

# Add markers
for quake in data_dict['features']:
    coords = quake['geometry']['coordinates']
    folium.CircleMarker(location=[coords[1],coords[0]], 
                        popup = quake['properties']['mag'],
                        weight=1,
                        fill=True,
                        fill_opacity=0.3,
                        color=quake['properties']['alert'],
                        radius = quake['properties']['mag'] * 2
                       ).add_to(world_map)


world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_089813e025320bff3ce8e688b3511d13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_089813e025320bff3ce8e688b3511d13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_089813e025320bff3ce8e688b3511d13 = L.map(
#                 &quot;map_089813e025320bff3ce8e688b3511d13&quot;,
#                 {
#                     center: [51.4769, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7f4ac12bb78843b792732bd4bfd2470 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c7f4ac12bb78843b792732bd4bfd2470.addTo(map_089813e025320bff3ce8e688b3511d13);
#
#
#             var circle_marker_c49f2dae2d9ce1cf53b6bcfaf2c47c96 = L.circleMarker(
#                 [0.8622, 93.1129],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_089813e025320bff3ce8e688b3511d13);
#
#
#         var popup_80165276283bc4ac68675d4b5b700177 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4389eaa3ba2d7ce861f9a7b31d16c58 = $(`&lt;div id=&quot;html_f4389eaa3ba2d7ce861f9a7b31d16c58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.5&lt;/div&gt;`)[0];
#                 popup_80165276283bc4ac68675d4b5b700177.setContent(html_f4389eaa3ba2d7ce861f9a7b31d16c58);
#
#
#
#         circle_marker_c49f2dae2d9ce1cf53b6bcfaf2c47c96.bindPopup(popup_80165276283bc4ac68675d4b5b700177)
#         ;
#
#
#
#
#             var circle_marker_28f4ed0db31be449b4839ba85e85dfcb = L.circleMarker(
#                 [-53.5274, -134.774],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.2, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_089813e025320bff3ce8e688b3511d13);
#
#
#         var popup_c6ffea3575165e71e7ff5bc941b3b93e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c205ce1c9b98c2efba25d4f3563cafc4 = $(`&lt;div id=&quot;html_c205ce1c9b98c2efba25d4f3563cafc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.6&lt;/div&gt;`)[0];
#                 popup_c6ffea3575165e71e7ff5bc941b3b93e.setContent(html_c205ce1c9b98c2efba25d4f3563cafc4);
#
#
#
#         circle_marker_28f4ed0db31be449b4839ba85e85dfcb.bindPopup(popup_c6ffea3575165e71e7ff5bc941b3b93e)
#         ;
#
#
#
#
#             var circle_marker_0df19a3d576d2116a1793a048fd4880c = L.circleMarker(
#                 [-3.3385, 128.858],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: null, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_089813e025320bff3ce8e688b3511d13);
#
#
#         var popup_7643c21e13f05e4bb15610a09ebd2739 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_acb37aa0f68390cbe7062482dc625fa6 = $(`&lt;div id=&quot;html_acb37aa0f68390cbe7062482dc625fa6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5&lt;/div&gt;`)[0];
#                 popup_7643c21e13f05e4bb15610a09ebd2739.setContent(html_acb37aa0f68390cbe7062482dc625fa6);
#
#
#
#         circle_marker_0df19a3d576d2116a1793a048fd4880c.bindPopup(popup_7643c21e13f05e4bb15610a09ebd2739)
#         ;
#
#
#
#
#             var circle_marker_2779203456eb76bcf2bad4173a6bc5d0 = L.circleMarker(
#                 [31.4154, 141.7419],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: null, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;,
